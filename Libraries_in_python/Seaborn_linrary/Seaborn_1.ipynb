# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
arr=np.arange(1,9)
print(arr)
sns.lineplot(arr)
sns.scatterplot(arr)
plt.show()
# Out:
# [1 2 3 4 5 6 7 8]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

arr=np.arange(1,9)
print(arr)
plt.figure(figsize=(6,4))
sns.lineplot(arr)
sns.scatterplot(arr)
plt.show()
# Out:
# [1 2 3 4 5 6 7 8]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

arr=np.array([4,5,6,2,6,9,1,6])
arr1=np.random.normal(size=(2, 3))
print(arr)
print(arr1)
sns.lineplot(arr)
sns.scatterplot(arr)
plt.show()
sns.lineplot(arr1)
sns.scatterplot(arr1)
plt.show()
# Out:
# [4 5 6 2 6 9 1 6]
# [[ 0.86196416  1.37857021  0.5501846 ]
#  [ 1.24460698 -0.28814432  0.32289832]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\sande\AppData\Local\Temp\ipykernel_10472\543109699.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)

# %%
# Barplot
