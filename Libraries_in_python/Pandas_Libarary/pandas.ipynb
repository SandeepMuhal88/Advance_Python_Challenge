# %%
import pandas as pd
import numpy as np
arr1=np.array([2,6,9,7,74])
arr2=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(arr1)
print(arr2)
# Out:
# [ 2  6  9  7 74]
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Data Frames
data={
    "Name": ["Tom", "nick", "krish", "jack"],
    "Age":[20,21,19,18],
    "City":["NY","LA","SF","DC"]
}
df=pd.DataFrame(data,index=['😎','😀','😎','😎'])
print(df)
# Out:
#     Name  Age City
# 😎    Tom   20   NY
# 😀   nick   21   LA
# 😎  krish   19   SF
# 😎   jack   18   DC

# %%
import pandas as pd
st=pd.read_csv('C:/Users/sande/Desktop/Advance_Python_Challnege/Libraries_in_python/Pandas_Libarary/Untitled spreadsheet - Sheet1.csv')
st
st.head()
# Out:
#             Name  Roll Number       City          State  Contact Number  \
# 0   Ishita Gupta          101       Pune    Maharashtra  +91 9355419430
# 1     Riya Mehta          102  Ahmedabad        Gujarat  +91 9335842331
# 2   Aadhya Patel          103      Delhi          Delhi  +91 9097531977
# 3  Ishita Chopra          104    Lucknow  Uttar Pradesh  +91 7649654275
# 4     Diya Gupta          105     Mumbai    Maharashtra  +91 7671986328
#
#                     Course
# 0         Computer Science
# 1  Electronics Engineering
# 2   Mechanical Engineering
# 3   Mechanical Engineering
# 4         Computer Science

# %%
import pandas as pd
data=pd.read_csv('C:/Users/sande/Desktop/Advance_Python_Challnege/Libraries_in_python/Pandas_Libarary/Citydata.csv')
data
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
print(st.info())
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            20 non-null     object
#  1   Roll Number     20 non-null     int64
#  2   City            20 non-null     object
#  3   State           20 non-null     object
#  4   Contact Number  20 non-null     object
#  5   Course          20 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name_of_city                    493 non-null    object
#  1   state_code                      493 non-null    int64
#  2   state_name                      493 non-null    object
# ...
