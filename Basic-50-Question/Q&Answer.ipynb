# %% [markdown]
# 1. Write a program to swap two variables without using a third variable.

# %%
def swap_number(a,b):
    print(f"The number : a={a},b={b}")
    a,b=b,a
    print(f"The swap number: a={a},b={b}")



swap_number(5,6)
# Out:
# The number : a=5,b=6
# The swap number: a=6,b=5

# %% [markdown]
# SWAP-NUMBER that is very interesting Topic

# %%
a=0
b=9
c=3
a,b,c=c,a,b
print(a,b,c)
# Out:
# 3 0 9

# %%
a=90
print(type(a))
b=9.8
a,b=b,a
print(a,b)
print(type(a))
# Out:
# <class 'int'>
# 9.8 90
# <class 'float'>

# %%
a=10
b=20
c=30
d=40
e=2
f=3
g=6
h=64
a,b,c,d,e,f,g,h=h,g,f,a,b,c,d,e
print(a,b,c,d,e,f,g,h)
# Out:
# 64 6 3 10 20 30 40 2

# %% [markdown]
# 2. Take a number as input and print whether it is positive, negative, or zero.

# %%
def check_number(num):
    if num<0:
        print("Given Number is Negative !!")
    elif num>0:
        print("Given Number is Positive ###")
    else:
        print("Given Number is Zero ***")
    

check_number(2)
check_number(-7)
check_number(0)
# Out:
# Given Number is Positive ###
# Given Number is Negative !!
# Given Number is Zero ***

# %% [markdown]
# 3. Take two integers and print their sum, difference, product, and quotient.

# %%
def operation(a, b):
    print("The sum of integer number :-", a + b)
    print("The difference of integer number :-", a - b)
    print("The product of integer number :-", a * b)
    # use float division for quotient (use '//' for integer division)
    print("The quotient of integer number :-", a / b)


operation(5, 7)
# Out:
# The sum of integer number :- 12
# The difference of integer number :- -2
# The product of integer number :- 35
# The quotient of integer number :- 0.7142857142857143

# %% [markdown]
# 4. Write a program to find the remainder without using % operator.

# %%
a=int(input("Enter a number:-"))
b = int(input("Enter divisor: "))
remainder = a - (a // b) * b

print("Remainder:", remainder)
# Out:
# Remainder: 458

# %% [markdown]
# Count vowels in a given string.

# %%
str=input("Enter a string:-")
a=0
for i in str:
    print(i)
    a+=1
print("Length of string is:",a)
# Out:
# S
# a
# n
# d
# e
# e
# p
#
# M
# U
# h
# a
# l
# Length of string is: 13

# %%
str=input("Enter a string:-")
vowels="aeiouAEIOU"
count=0

for char in str:
    if char in vowels:
        print(char)
        count+=1
print("Total number of vowels in string is:",count)
# Out:
# a
# e
# e
# u
# a
# i
# a
# o
# o
# a
# Total number of vowels in string is: 10

# %% [markdown]
# Reverse a string without using slicing.

# %%
str1=input("Enter first string:-")

print("Before Reverse String 1:",str1)
print("After Reverse String 1:",str1[::-1])
# Out:
# Before Reverse String 1: Sandeep Muhal
# After Reverse String 1: lahuM peednaS

# %% [markdown]
# Check if a string is a palindrome.
