# %% [markdown]
# ### What is the output of: x = 'Hello'; y = 'World'; z = x + y; print(z)?
# - A)
# - B)
# - C)
# - D)

# %%
x='Hello'
y='World'

z=x+y
print(z)
# Out:
# HelloWorld

# %% [markdown]
# "a) x = y = z = "Orange" b) x, y, z = "Orange" c) x, y, z = "Orange", "Banana", "Cherry" d) None of the above Which of the following will throw an error?"
# - A)
# - B)
# - C)
# - D)

# %%
x=y=z="Orange"
x,y,z="Orange"
# x,y,z=""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 x=y=z="Orange"
# ----> 2 x,y,z="Orange"
#       3 x,y,z=""
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# ### What is the output of boolean code with if-elif?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### What is the type of (1,2,3)?
# - A)
# - B)
# - C)
# - D)

# %%
x = (1, 2, 3)
print(type(x))

# What is the output of the following Python code?
# Out:
# <class 'tuple'>

# %% [markdown]
# ### What will print({1:'one',2:'two'}[1])?
# - A)
# - B)
# - C)
# - D)

# %%
x = {1: "one", 2: "two"} 
print (x[1])

# What is the output of the following Python code?
# Out:
# one

# %% [markdown]
# ### Output of True + False?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of int('123') + 1?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of list('Hello')?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of bool(123)?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of int('123'+'456')?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of (10==20)?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of True and False?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Value of x after loop: x=10; while x>5: x-=1?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Break example loop output?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Continue example loop output?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Loop checking integer type output?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of lambda a:a+10 with a=5?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of recursive lambda fun(4)?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of class Test attribute code?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of class Test private variable?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of inheritance example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Which function opens a file?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### How to create new directory in Python?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of try-except ZeroDivisionError?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of try-except ValueError?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Keyword to raise exceptions?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Keyword to handle exceptions?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Mode to open file for reading?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of 'Hello'[1:4]?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of list slicing example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of dictionary operation?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of boolean expression?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of for loop example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of tuple unpacking code?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of integer division example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of modulo operation?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of list comprehension example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of set operation?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of string multiplication?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of recursion example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of map() example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Result of filter() example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of zip() example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### Output of slicing example?
# - A)
# - B)
# - C)
# - D)

# %% [markdown]
# ### What happens when dict['missing_key'] is accessed?
# - A)
# - B)
# - C)
# - D)
