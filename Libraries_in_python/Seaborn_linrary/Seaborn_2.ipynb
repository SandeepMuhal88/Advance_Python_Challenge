# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = sns.load_dataset("penguins")

# Countplot for species
sns.countplot(data=data, x="species", hue="sex")
plt.title("Count of Penguin Species by Sex")
plt.show()

# %% [markdown]
# State
